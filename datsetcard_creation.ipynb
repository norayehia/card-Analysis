# %% [markdown]
# <a href="https://colab.research.google.com/github/norayehia/card-Analysis/blob/main/datsetcard_creation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Define levels with increasing health impacts
levels = range(1, 16)
increments = [3, 6, 9, 12]  # Consistent increments for all categories

categories = {
    "Healthy": [
        ("Daily walking for heart health", 3, "https://www.mayoclinic.org/healthy-lifestyle"),
        ("Balanced diet", 3, "https://www.webmd.com"),
        ("Regular sleep schedule", 3, "https://www.sleepfoundation.org"),
        ("Hydration", 3, "https://www.healthline.com"),
        ("Yoga for flexibility", 3, "https://www.yoga.com"),

        # Additional entries for Healthy category
        ("Eating more fruits and vegetables", 3, "https://www.healthline.com"),
        ("Regular exercise", 3, "https://www.webmd.com"),
        ("Limiting processed foods", 3, "https://www.cdc.gov"),
        ("Stress management techniques", 3, "https://www.apa.org"),
        ("Mindfulness meditation", 3, "https://www.meditation.com"),
        ("Adequate sleep duration", 3, "https://www.sleepfoundation.org"),
        ("Reducing sugar intake", 3, "https://www.healthline.com"),
        ("Increasing water intake", 3, "https://www.healthline.com"),
        ("Healthy cooking methods", 3, "https://www.cdc.gov"),
        ("Maintaining a balanced diet", 3, "https://www.webmd.com"),
        ("Prioritizing self-care", 3, "https://www.mentalhealth.gov"),
        ("Regular check-ups", 3, "https://www.cdc.gov"),
        ("Limiting caffeine consumption", 3, "https://www.mayoclinic.org"),
        ("Consuming lean proteins", 3, "https://www.webmd.com"),
        ("Eating whole grains", 3, "https://www.healthline.com"),
        ("Limiting processed carbs", 3, "https://www.webmd.com"),
        ("Staying active indoors", 3, "https://www.cdc.gov"),
        ("Maintaining a sleep routine", 3, "https://www.sleepfoundation.org"),
        ("Building strong social connections", 3, "https://www.mentalhealth.gov"),
        ("Practicing gratitude", 3, "https://www.mentalhealth.org.uk")
    ],
    "Non-Healthy": [
        ("Excessive junk food consumption", -3, "https://www.heart.org"),
        ("Sedentary lifestyle", -3, "https://www.cdc.gov"),
        ("Poor sleep habits", -3, "https://www.sleepfoundation.org"),
        ("Smoking", -3, "https://www.cdc.gov"),
        ("Excessive alcohol consumption", -3, "https://www.cdc.gov"),

        # Additional entries for Non-Healthy category
        ("Skipping meals", -3, "https://www.webmd.com"),
        ("Excessive screen time", -3, "https://www.cdc.gov"),
        ("Overeating unhealthy snacks", -3, "https://www.heart.org"),
        ("Lack of hydration", -3, "https://www.cdc.gov"),
        ("Stress eating", -3, "https://www.cdc.gov"),
        ("Poor mental health management", -3, "https://www.mentalhealth.gov"),
        ("Ignoring physical activity", -3, "https://www.cdc.gov"),
        ("Excessive caffeine consumption", -3, "https://www.mayoclinic.org"),
        ("Inadequate sleep duration", -3, "https://www.sleepfoundation.org"),
        ("Using unhealthy cooking methods", -3, "https://www.cdc.gov"),
        ("Consuming processed foods", -3, "https://www.cdc.gov"),
        ("Skipping exercise", -3, "https://www.cdc.gov"),
        ("Excessive alcohol use", -3, "https://www.cdc.gov"),
        ("Ignoring safety precautions", -3, "https://www.safekids.org"),
        ("Excessive sugar intake", -3, "https://www.healthline.com"),
        ("Poor dietary choices", -3, "https://www.webmd.com"),
        ("Poor work-life balance", -3, "https://www.mentalhealth.gov"),
        ("Ignoring preventive healthcare", -3, "https://www.cdc.gov"),
        ("Overindulgence in unhealthy habits", -3, "https://www.heart.org"),
        ("Lack of physical activity", -3, "https://www.cdc.gov")
    ],
    "Ridiculous": [
        ("Eating dirt", -3, "https://www.healthline.com"),
        ("Jumping off cliffs", -6, "https://www.abcnews.com"),
        ("Staying awake for 72 hours", -9, "https://www.sleepfoundation.org"),
        ("Drinking bleach", -12, "https://www.poison.org"),
        ("Running with scissors", -15, "https://www.safekids.org"),

        # Additional entries for Ridiculous category
        ("Consuming toxic substances", -18, "https://www.poison.org"),
        ("Engaging in high-risk activities", -21, "https://www.abcnews.com"),
        ("Overexposing to hazardous materials", -24, "https://www.poison.org"),
        ("Attempting extreme physical stunts", -27, "https://www.safekids.org"),
        ("Ignoring safety warnings", -30, "https://www.safekids.org"),
        ("Improper storage of dangerous items", -33, "https://www.poison.org"),
        ("Participating in reckless adventures", -36, "https://www.safekids.org"),
        ("Using unsafe methods for activities", -39, "https://www.abcnews.com"),
        ("Overlooking safety protocols", -42, "https://www.safekids.org"),
        ("Ignoring professional advice", -45, "https://www.abcnews.com"),
        ("Overexposing to extreme conditions", -48, "https://www.safekids.org"),
        ("Engaging in hazardous recreational activities", -51, "https://www.poison.org"),
        ("Absence of safety equipment", -54, "https://www.safekids.org"),
        ("Not following safety precautions", -57, "https://www.abcnews.com"),
        ("Neglecting preventive health practices", -60, "https://www.mentalhealth.gov"),
        ("Excessive exposure to harmful substances", -63, "https://www.healthline.com"),
        ("Engaging in unsafe environments", -66, "https://www.safekids.org"),
        ("Failure to heed safety warnings", -69, "https://www.safekids.org"),
        ("Participating in extreme risky behaviors", -72, "https://www.safekids.org"),
        ("Neglecting safety advice and warnings", -75, "https://www.safekids.org"),
    ]
}

# Generate each level for each category with incremental health impacts
data = []
for category, entries in categories.items():
    for card_name, health_impact, link in entries:
        current_health_impact = health_impact
        for level in levels:
            health_effect = 'improves' if current_health_impact > 0 else 'reduces'
            description = f"At level {level}, '{card_name}' {health_effect} health by {abs(current_health_impact)} points."
            data.append([category, card_name, level, description, link])
            current_health_impact += increments[0]  # Use consistent increment for all levels

# Create DataFrame
df = pd.DataFrame(data, columns=["Category", "Card Name", "Level", "Description", "Referral Link"])

# Save to CSV
csv_file_path = '12generated_health_data_with_custom_incremental_points.csv'
df.to_csv(csv_file_path, index=False)

print(f"DataFrame saved to {csv_file_path}")
# Out:
# DataFrame saved to 12generated_health_data_with_custom_incremental_points.csv

# %%
df.head(10)
# Out:
#   Category                       Card Name  Level  \
# 0  Healthy  Daily walking for heart health      1
# 1  Healthy  Daily walking for heart health      2
# 2  Healthy  Daily walking for heart health      3
# 3  Healthy  Daily walking for heart health      4
# 4  Healthy  Daily walking for heart health      5
# 5  Healthy  Daily walking for heart health      6
# 6  Healthy  Daily walking for heart health      7
# 7  Healthy  Daily walking for heart health      8
# 8  Healthy  Daily walking for heart health      9
# 9  Healthy  Daily walking for heart health     10
#
#                                          Description  \
# 0  At level 1, 'Daily walking for heart health' i...
# 1  At level 2, 'Daily walking for heart health' i...
# 2  At level 3, 'Daily walking for heart health' i...
# 3  At level 4, 'Daily walking for heart health' i...
# 4  At level 5, 'Daily walking for heart health' i...
# 5  At level 6, 'Daily walking for heart health' i...
# ...

# %% [markdown]
# =======================================================================

# %%
import pandas as pd

# Define levels with increasing health impacts
levels = range(1, 16)
increments = [3, 6, 9, 12]  # Consistent increments for all categories

categories = {
    "Healthy": [
        ("Daily walking for heart health", 3, "https://www.mayoclinic.org/healthy-lifestyle"),
        ("Balanced diet", 3, "https://www.webmd.com"),
        ("Regular sleep schedule", 3, "https://www.sleepfoundation.org"),
        ("Hydration", 3, "https://www.healthline.com"),
        ("Yoga for flexibility", 3, "https://www.yoga.com"),

        # Additional entries for Healthy category
        ("Eating more fruits and vegetables", 3, "https://www.healthline.com"),
        ("Regular exercise", 3, "https://www.webmd.com"),
        ("Limiting processed foods", 3, "https://www.cdc.gov"),
        ("Stress management techniques", 3, "https://www.apa.org"),
        ("Mindfulness meditation", 3, "https://www.meditation.com"),
        ("Adequate sleep duration", 3, "https://www.sleepfoundation.org"),
        ("Reducing sugar intake", 3, "https://www.healthline.com"),
        ("Increasing water intake", 3, "https://www.healthline.com"),
        ("Healthy cooking methods", 3, "https://www.cdc.gov"),
        ("Maintaining a balanced diet", 3, "https://www.webmd.com"),
        ("Prioritizing self-care", 3, "https://www.mentalhealth.gov"),
        ("Regular check-ups", 3, "https://www.cdc.gov"),
        ("Limiting caffeine consumption", 3, "https://www.mayoclinic.org"),
        ("Consuming lean proteins", 3, "https://www.webmd.com"),
        ("Eating whole grains", 3, "https://www.healthline.com"),
        ("Limiting processed carbs", 3, "https://www.webmd.com"),
        ("Staying active indoors", 3, "https://www.cdc.gov"),
        ("Maintaining a sleep routine", 3, "https://www.sleepfoundation.org"),
        ("Building strong social connections", 3, "https://www.mentalhealth.gov"),
        ("Practicing gratitude", 3, "https://www.mentalhealth.org.uk"),

        # Additional entries to make total 40
        ("Eating a balanced breakfast", 3, "https://www.healthline.com"),
        ("Limiting sodium intake", 3, "https://www.cdc.gov"),
        ("Avoiding processed meats", 3, "https://www.webmd.com"),
        ("Incorporating healthy snacks", 3, "https://www.healthline.com"),
        ("Eating fermented foods", 3, "https://www.healthline.com"),
        ("Prioritizing fiber intake", 3, "https://www.healthline.com"),
        ("Eating healthy fats", 3, "https://www.healthline.com"),
        ("Reducing saturated fats", 3, "https://www.cdc.gov"),
        ("Eating enough iron-rich foods", 3, "https://www.cdc.gov"),
        ("Choosing whole fruits over juices", 3, "https://www.webmd.com"),
        ("Focusing on protein-rich foods", 3, "https://www.webmd.com"),
        ("Ensuring proper vitamin intake", 3, "https://www.healthline.com"),
        ("Incorporating leafy greens", 3, "https://www.webmd.com"),
        ("Prioritizing omega-3 fatty acids", 3, "https://www.healthline.com"),
        ("Monitoring portion sizes", 3, "https://www.webmd.com"),
        ("Consuming more nuts and seeds", 3, "https://www.cdc.gov"),
        ("Avoiding high sugar snacks", 3, "https://www.webmd.com"),
        ("Limiting processed sugars", 3, "https://www.cdc.gov"),
        ("Eating legumes regularly", 3, "https://www.webmd.com"),
        ("Incorporating plant-based proteins", 3, "https://www.healthline.com"),
        ("Monitoring hydration levels", 3, "https://www.healthline.com"),
        ("Incorporating antioxidant-rich foods", 3, "https://www.cdc.gov"),
        ("Reducing added sugars", 3, "https://www.webmd.com"),
        ("Consuming whole grains regularly", 3, "https://www.webmd.com"),
        ("Limiting fried foods", 3, "https://www.cdc.gov"),
        ("Prioritizing vitamin C intake", 3, "https://www.healthline.com"),
        ("Including more fruits in diet", 3, "https://www.healthline.com"),
        ("Focusing on lean protein sources", 3, "https://www.webmd.com"),
        ("Limiting salt intake", 3, "https://www.cdc.gov"),
        ("Monitoring blood sugar levels", 3, "https://www.webmd.com"),
        ("Prioritizing food safety practices", 3, "https://www.webmd.com"),
        ("Eating more fish and seafood", 3, "https://www.webmd.com"),
        ("Maintaining a healthy weight", 3, "https://www.healthline.com"),
        ("Eating nutrient-dense foods", 3, "https://www.healthline.com"),
    ],
    "Non-Healthy": [
        ("Excessive junk food consumption", -3, "https://www.heart.org"),
        ("Sedentary lifestyle", -3, "https://www.cdc.gov"),
        ("Poor sleep habits", -3, "https://www.sleepfoundation.org"),
        ("Smoking", -3, "https://www.cdc.gov"),
        ("Excessive alcohol consumption", -3, "https://www.cdc.gov"),

        # Additional entries for Non-Healthy category
        ("Skipping meals", -3, "https://www.webmd.com"),
        ("Excessive screen time", -3, "https://www.cdc.gov"),
        ("Overeating unhealthy snacks", -3, "https://www.heart.org"),
        ("Lack of hydration", -3, "https://www.cdc.gov"),
        ("Stress eating", -3, "https://www.cdc.gov"),
        ("Poor mental health management", -3, "https://www.mentalhealth.gov"),
        ("Ignoring physical activity", -3, "https://www.cdc.gov"),
        ("Excessive caffeine consumption", -3, "https://www.mayoclinic.org"),
        ("Inadequate sleep duration", -3, "https://www.sleepfoundation.org"),
        ("Using unhealthy cooking methods", -3, "https://www.cdc.gov"),
        ("Consuming processed foods", -3, "https://www.cdc.gov"),
        ("Skipping exercise", -3, "https://www.cdc.gov"),
        ("Excessive alcohol use", -3, "https://www.cdc.gov"),
        ("Ignoring safety precautions", -3, "https://www.safekids.org"),
        ("Excessive sugar intake", -3, "https://www.healthline.com"),
        ("Poor dietary choices", -3, "https://www.webmd.com"),
        ("Poor work-life balance", -3, "https://www.mentalhealth.gov"),
        ("Ignoring preventive healthcare", -3, "https://www.cdc.gov"),
        ("Overindulgence in unhealthy habits", -3, "https://www.heart.org"),
        ("Lack of physical activity", -3, "https://www.cdc.gov"),

        # Additional entries to make total 40
        ("Ignoring meal planning", -3, "https://www.webmd.com"),
        ("Overeating processed snacks", -3, "https://www.heart.org"),
        ("Neglecting mental health resources", -3, "https://www.mentalhealth.gov"),
        ("Neglecting hydration needs", -3, "https://www.cdc.gov"),
        ("Skipping meals regularly", -3, "https://www.webmd.com"),
        ("Excessive snacking between meals", -3, "https://www.heart.org"),
        ("Lack of fiber intake", -3, "https://www.webmd.com"),
        ("Neglecting nutrient-dense foods", -3, "https://www.webmd.com"),
        ("Excessive high-sugar snacks", -3, "https://www.cdc.gov"),
        ("Skipping balanced meals", -3, "https://www.webmd.com"),
        ("Overconsuming unhealthy drinks", -3, "https://www.cdc.gov"),
        ("Not monitoring portion sizes", -3, "https://www.webmd.com"),
        ("Skipping physical activity routines", -3, "https://www.cdc.gov"),
        ("Ignoring sleep hygiene", -3, "https://www.sleepfoundation.org"),
        ("Not prioritizing protein intake", -3, "https://www.webmd.com"),
        ("Neglecting meal planning", -3, "https://www.webmd.com"),
        ("Skipping meal preparation", -3, "https://www.cdc.gov"),
        ("Excessive sedentary behaviors", -3, "https://www.cdc.gov"),
        ("Skipping water intake", -3, "https://www.cdc.gov"),
        ("Ignoring dietary recommendations", -3, "https://www.cdc.gov"),
        ("Excessive consumption of processed carbs", -3, "https://www.webmd.com"),
        ("Skipping fruit and vegetable consumption", -3, "https://www.cdc.gov"),
        ("Excessive salt intake", -3, "https://www.cdc.gov"),
        ("Skipping physical fitness routines", -3, "https://www.cdc.gov"),
        ("Ignoring health and safety guidelines", -3, "https://www.cdc.gov"),
        ("Skipping preventive health practices", -3, "https://www.cdc.gov"),
        ("Ignoring social health connections", -3, "https://www.mentalhealth.gov"),
        ("Skipping mental health care", -3, "https://www.mentalhealth.gov"),
        ("Overconsuming unhealthy fats", -3, "https://www.cdc.gov"),
        ("Neglecting healthy sleep habits", -3, "https://www.sleepfoundation.org"),
        ("Overconsuming processed sugar", -3, "https://www.cdc.gov"),
        ("Skipping hydration practices", -3, "https://www.cdc.gov"),
        ("Overconsuming processed foods", -3, "https://www.cdc.gov"),
    ],
    "Ridiculous": [
        ("Eating dirt", -3, "https://www.healthline.com"),
        ("Jumping off cliffs", -6, "https://www.abcnews.com"),
        ("Staying awake for 72 hours", -9, "https://www.sleepfoundation.org"),
        ("Drinking bleach", -12, "https://www.poison.org"),
        ("Running with scissors", -15, "https://www.safekids.org"),

        # Additional entries for Ridiculous category
        ("Consuming toxic substances", -18, "https://www.poison.org"),
        ("Engaging in high-risk activities", -21, "https://www.abcnews.com"),
        ("Overexposing to hazardous materials", -24, "https://www.poison.org"),
        ("Attempting extreme physical stunts", -27, "https://www.safekids.org"),
        ("Ignoring safety warnings", -30, "https://www.safekids.org"),
        ("Improper storage of dangerous items", -33, "https://www.poison.org"),
        ("Participating in reckless adventures", -36, "https://www.safekids.org"),
        ("Using unsafe methods for activities", -39, "https://www.abcnews.com"),
        ("Overlooking safety protocols", -42, "https://www.safekids.org"),
        ("Ignoring professional advice", -45, "https://www.abcnews.com"),
        ("Overexposing to extreme conditions", -48, "https://www.safekids.org"),
        ("Engaging in hazardous recreational activities", -51, "https://www.poison.org"),
        ("Absence of safety equipment", -54, "https://www.safekids.org"),
        ("Not following safety precautions", -57, "https://www.abcnews.com"),
        ("Neglecting preventive health practices", -60, "https://www.mentalhealth.gov"),
        ("Excessive exposure to harmful substances", -63, "https://www.healthline.com"),
        ("Engaging in unsafe environments", -66, "https://www.safekids.org"),
        ("Failure to heed safety warnings", -69, "https://www.safekids.org"),
        ("Participating in extreme risky behaviors", -72, "https://www.safekids.org"),
        ("Neglecting safety advice and warnings", -75, "https://www.safekids.org"),

        # Additional entries to make total 40
        ("Handling hazardous chemicals", -78, "https://www.poison.org"),
        ("Engaging in reckless physical stunts", -81, "https://www.abcnews.com"),
        ("Exposing to toxic environments", -84, "https://www.poison.org"),
        ("Overexposing to extreme physical conditions", -87, "https://www.safekids.org"),
        ("Failure to follow safety rules", -90, "https://www.safekids.org"),
        ("Ignoring hazardous warnings", -93, "https://www.abcnews.com"),
        ("Excessive exposure to dangerous substances", -96, "https://www.safekids.org"),
        ("Engaging in unsafe lifestyle practices", -99, "https://www.safekids.org"),
        ("Neglecting safety education", -102, "https://www.safekids.org"),
        ("Participating in hazardous activities", -105, "https://www.safekids.org"),
        ("Absence of safety protocols", -108, "https://www.safekids.org"),
        ("Failure to heed safety guidelines", -111, "https://www.safekids.org"),
        ("Exposing to extreme risks", -114, "https://www.safekids.org"),
        ("Engaging in dangerous recreational activities", -117, "https://www.poison.org"),
        ("Ignoring safety precautions consistently", -120, "https://www.safekids.org"),
        ("Overexposing to hazardous environments", -123, "https://www.poison.org"),
        ("Participating in extreme reckless behaviors", -126, "https://www.safekids.org"),
        ("Neglecting all safety warnings", -129, "https://www.safekids.org"),
        ("Exposing to dangerous environments repeatedly", -132, "https://www.safekids.org"),
        ("Failure to follow safety recommendations", -135, "https://www.safekids.org"),
    ]
}

# Generate each level for each category with incremental health impacts
data = []
for category, entries in categories.items():
    for card_name, health_impact, link in entries:
        current_health_impact = health_impact
        for level in levels:
            health_effect = 'improves' if current_health_impact > 0 else 'reduces'
            description = f"At level {level}, '{card_name}' {health_effect} health by {abs(current_health_impact)} points."
            data.append([category, card_name, level, description, link])
            current_health_impact += increments[0]  # Use consistent increment for all levels

# Create DataFrame
df = pd.DataFrame(data, columns=["Category", "Card Name", "Level", "Description", "Referral Link"])

# Save to CSV
csv_file_path = '40_generated_health_data_with_custom_incremental_points.csv'
df.to_csv(csv_file_path, index=False)

print(f"DataFrame saved to {csv_file_path}")
# Out:
# DataFrame saved to 40_generated_health_data_with_custom_incremental_points.csv

# %%
df.head(10)
# Out:
#   Category                       Card Name  Level  \
# 0  Healthy  Daily walking for heart health      1
# 1  Healthy  Daily walking for heart health      2
# 2  Healthy  Daily walking for heart health      3
# 3  Healthy  Daily walking for heart health      4
# 4  Healthy  Daily walking for heart health      5
# 5  Healthy  Daily walking for heart health      6
# 6  Healthy  Daily walking for heart health      7
# 7  Healthy  Daily walking for heart health      8
# 8  Healthy  Daily walking for heart health      9
# 9  Healthy  Daily walking for heart health     10
#
#                                          Description  \
# 0  At level 1, 'Daily walking for heart health' i...
# 1  At level 2, 'Daily walking for heart health' i...
# 2  At level 3, 'Daily walking for heart health' i...
# 3  At level 4, 'Daily walking for heart health' i...
# 4  At level 5, 'Daily walking for heart health' i...
# 5  At level 6, 'Daily walking for heart health' i...
# ...

# %%
# @title Level

from matplotlib import pyplot as plt
df['Level'].plot(kind='hist', bins=20, title='Level')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Category

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('Category').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
